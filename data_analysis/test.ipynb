# %%
import pandas as pd
import numpy as np

# %%
my_array = np.array([ 10 , 20 , 30 , 40 , 50 ])
my_series = pd.Series(my_array) 
print (my_series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
